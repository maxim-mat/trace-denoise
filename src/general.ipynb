# %%
import pickle as pkl
import torch
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from scipy.stats import entropy
import streamlit as st
import pickle as pkl

import torch
from sklearn.model_selection import train_test_split

from denoisers.ConditionalUnetDenoiser import ConditionalUnetDenoiser
from denoisers.ConditionalUnetMatrixDenoiser import ConditionalUnetMatrixDenoiser
from utils.graph_utils import get_process_model_reachability_graph_transition_matrix, get_process_model_petri_net_transition_matrix
from utils.pm_utils import discover_dk_process, remove_duplicates_dataset, pad_to_multiple_of_n
from utils.Config import Config
import plotly.express as px
import plotly.graph_objects as go
from dataset.dataset import SaladsDataset
from ddpm.ddpm_multinomial import Diffusion
import os
import json
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
from utils.pm_utils import conformance_measure
import numpy as np
from scipy.stats import wasserstein_distance
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

# %%
with open("../data/pickles/50_salads_unified.pkl", "rb") as f:
    salads_data = pkl.load(f)
salads_dataset = SaladsDataset(salads_data['target'], salads_data['stochastic'])
salads_train, salads_test = train_test_split(salads_dataset, train_size=0.75, shuffle=True, random_state=42)

# %%
data_paths = ["50_salads_synth_from_det_{:.3f}.pkl".format(x) for x in [0.68, 0.72, 0.75, 0.8, 0.83]]
datas = []
for data_path in data_paths:
    with open(f"../data/synthetic/{data_path}", "rb") as f:
        data = pkl.load(f)
        datas.append(data)

# %%
datas.append(salads_data)
augmented_data = {"target": [], "stochastic": []}
for data in datas:
    augmented_data["target"].extend(data["target"])
    augmented_data["stochastic"].extend(data["stochastic"])

# %%
with open("../data/pickles/50_salads_aug.pkl", "wb") as f:
    pkl.dump(augmented_data, f)

# %%
def load_experiment_config(target_dir):
    config_path = os.path.join(target_dir, "cfg.json")
    if os.path.exists(config_path):
        with open(config_path, "r") as f:
            return Config(**json.load(f))
    else:
        st.warning("Configuration file not found.")
        return None
target_dir = r"D:\Projects\trace-denoise\final_runs\50_salads_unified_rg"
cfg = load_experiment_config(target_dir)

# %%
dk_process_model, dk_init_marking, dk_final_marking = discover_dk_process(salads_train, cfg,
                                                                          preprocess=remove_duplicates_dataset)

# %%
from pm4py.objects.petri_net.utils import reachability_graph
import networkx as nx

rg = reachability_graph.construct_reachability_graph(dk_process_model, dk_init_marking)

rg_nx = nx.MultiDiGraph()

for state in rg.states:
    rg_nx.add_node(state.name)

transition_names = {tuple(s.strip(" '") for s in transition.name.strip("()").split(","))[1] for transition in
                    rg.transitions}
transition_name_index = {name: idx for idx, name in enumerate(sorted(transition_names))}

# %%
rg.transitions
# Out:
# {(38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (skip_14, None),
#  (skip_3, None),
#  (skip_3, None),
#  (skip_20, None),
#  (skip_27, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_8, None),
#  (skip_19, None),
#  (skip_19, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (init_loop_12, None),
#  (skip_26, None),
#  (skip_27, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (skip_3, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_20, None),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (skip_28, None),
#  (skip_3, None),
#  (skip_20, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_11, None),
#  (skip_29, None),
#  (skip_26, None),
#  (init_loop_17, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (init_loop_22, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (skip_16, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (init_loop_17, None),
#  (init_loop_12, None),
#  (skip_3, None),
#  (skip_28, None),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (skip_16, None),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_30, None),
#  (skip_3, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_11, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_17, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_29, None),
#  (init_loop_17, None),
#  (skip_21, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_16, None),
#  (skip_3, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_16, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_15, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_30, None),
#  (skip_15, None),
#  (init_loop_12, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_14, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_3, None),
#  (skip_3, None),
#  (skip_3, None),
#  (ec9d88c7-ba4a-4351-9915-ca1c0d8a7f7d, 'add_pepper'),
#  (skip_3, None),
#  (init_loop_17, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_11, None),
#  (init_loop_12, None),
#  (skip_14, None),
#  (091c348a-43a3-435f-8ae8-b30134593ae7, 'place_cheese_into_bowl'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (init_loop_6, None),
#  (skip_16, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (573d264d-38ac-478c-b3c9-523e1999aae0, 'peel_cucumber'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (e1dab229-cb32-4ffd-8f86-14df199a838c, 'cut_tomato'),
#  (skip_3, None),
#  (skip_3, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (f08eb743-77d0-4e3f-846e-b8638d9fe3df, 'add_salt'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (skip_11, None),
#  (init_loop_12, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_17, None),
#  (init_loop_6, None),
#  (init_loop_17, None),
#  (skip_8, None),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (tauSplit_9, None),
#  (skip_16, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_16, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_3, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_15, None),
#  (ec9d88c7-ba4a-4351-9915-ca1c0d8a7f7d, 'add_pepper'),
#  (skip_3, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (091c348a-43a3-435f-8ae8-b30134593ae7, 'place_cheese_into_bowl'),
#  (skip_14, None),
#  (skip_11, None),
#  (init_loop_12, None),
#  (init_loop_22, None),
#  (e1dab229-cb32-4ffd-8f86-14df199a838c, 'cut_tomato'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_17, None),
#  (skip_21, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_16, None),
#  (init_loop_17, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (573d264d-38ac-478c-b3c9-523e1999aae0, 'peel_cucumber'),
#  (init_loop_22, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (f08eb743-77d0-4e3f-846e-b8638d9fe3df, 'add_salt'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_16, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (skip_3, None),
#  (skip_3, None),
#  (skip_11, None),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (tauJoin_10, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_21, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (tauSplit_9, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_17, None),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_8, None),
#  (skip_3, None),
#  (skip_16, None),
#  (init_loop_22, None),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (skip_3, None),
#  (skip_3, None),
#  (init_loop_22, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_15, None),
#  (init_loop_22, None),
#  (skip_21, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_27, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_26, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_21, None),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (tauJoin_10, None),
#  (skip_21, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_14, None),
#  (skip_3, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (tauJoin_10, None),
#  (skip_3, None),
#  (skip_28, None),
#  (skip_3, None),
#  (skip_15, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_25, None),
#  (skip_29, None),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_24, None),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_30, None),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (skip_3, None),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (skip_14, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (skip_3, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (skip_3, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_19, None),
#  (skip_3, None),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_25, None),
#  (skip_15, None),
#  (skip_20, None),
#  (skip_25, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_12, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_17, None),
#  (skip_14, None),
#  (skip_24, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_16, None),
#  (skip_3, None),
#  (skip_24, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_12, None),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (init_loop_22, None),
#  (skip_11, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_3, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_19, None),
#  (skip_3, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (init_loop_17, None),
#  (skip_25, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_11, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_16, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_21, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_24, None),
#  (skip_19, None),
#  (skip_3, None),
#  (init_loop_12, None),
#  (skip_20, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_11, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_21, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (skip_11, None),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_22, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (skip_21, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_30, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_19, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_17, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (init_loop_17, None),
#  (skip_20, None),
#  (skip_15, None),
#  (skip_16, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_16, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_14, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (skip_3, None),
#  (init_loop_22, None),
#  (init_loop_12, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_21, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (init_loop_6, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_12, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_22, None),
#  (skip_11, None),
#  (skip_11, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (init_loop_17, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_19, None),
#  (skip_16, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_3, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_22, None),
#  (init_loop_6, None),
#  (skip_20, None),
#  (skip_15, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_21, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_21, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_12, None),
#  (skip_3, None),
#  (skip_3, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (skip_11, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_6, None),
#  (skip_19, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_14, None),
#  (skip_14, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_3, None),
#  (skip_15, None),
#  (skip_3, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (ec9d88c7-ba4a-4351-9915-ca1c0d8a7f7d, 'add_pepper'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_20, None),
#  (tauJoin_10, None),
#  (e1dab229-cb32-4ffd-8f86-14df199a838c, 'cut_tomato'),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (091c348a-43a3-435f-8ae8-b30134593ae7, 'place_cheese_into_bowl'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (skip_19, None),
#  (f08eb743-77d0-4e3f-846e-b8638d9fe3df, 'add_salt'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (573d264d-38ac-478c-b3c9-523e1999aae0, 'peel_cucumber'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (skip_20, None),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (tauSplit_9, None),
#  (skip_15, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_14, None),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (skip_15, None),
#  (skip_8, None),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (skip_3, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (skip_27, None),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_14, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_14, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_25, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_26, None),
#  (skip_15, None),
#  (skip_3, None),
#  (skip_14, None),
#  (skip_3, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_24, None),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (skip_28, None),
#  (skip_25, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_15, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_29, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (skip_24, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (init_loop_17, None),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_14, None),
#  (skip_16, None),
#  (skip_30, None),
#  (skip_3, None),
#  (skip_15, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_25, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_3, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (init_loop_17, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (skip_16, None),
#  (skip_24, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_17, None),
#  (skip_3, None),
#  (skip_15, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_12, None),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (skip_14, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (skip_19, None),
#  (skip_16, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_27, None),
#  (skip_3, None),
#  (skip_14, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_11, None),
#  (skip_21, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_26, None),
#  (init_loop_17, None),
#  (skip_3, None),
#  (init_loop_22, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_15, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_28, None),
#  (skip_16, None),
#  (skip_20, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (init_loop_12, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_29, None),
#  (skip_11, None),
#  (init_loop_22, None),
#  (init_loop_12, None),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (skip_21, None),
#  (init_loop_22, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_30, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (skip_3, None),
#  (skip_3, None),
#  (init_loop_12, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (tauJoin_10, None),
#  (skip_11, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_11, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (init_loop_6, None),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (skip_21, None),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_25, None),
#  (skip_3, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_12, None),
#  (init_loop_12, None),
#  (ec9d88c7-ba4a-4351-9915-ca1c0d8a7f7d, 'add_pepper'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_24, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (091c348a-43a3-435f-8ae8-b30134593ae7, 'place_cheese_into_bowl'),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_6, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (e1dab229-cb32-4ffd-8f86-14df199a838c, 'cut_tomato'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (skip_3, None),
#  (skip_11, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (573d264d-38ac-478c-b3c9-523e1999aae0, 'peel_cucumber'),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (f08eb743-77d0-4e3f-846e-b8638d9fe3df, 'add_salt'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_11, None),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (init_loop_12, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_11, None),
#  (skip_25, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (tauSplit_9, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (skip_24, None),
#  (skip_8, None),
#  (skip_3, None),
#  (init_loop_12, None),
#  (skip_3, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_11, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (init_loop_12, None),
#  (skip_27, None),
#  (ec9d88c7-ba4a-4351-9915-ca1c0d8a7f7d, 'add_pepper'),
#  (init_loop_22, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_26, None),
#  (e1dab229-cb32-4ffd-8f86-14df199a838c, 'cut_tomato'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_15, None),
#  (091c348a-43a3-435f-8ae8-b30134593ae7, 'place_cheese_into_bowl'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_11, None),
#  (skip_20, None),
#  (573d264d-38ac-478c-b3c9-523e1999aae0, 'peel_cucumber'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_21, None),
#  (skip_14, None),
#  (f08eb743-77d0-4e3f-846e-b8638d9fe3df, 'add_salt'),
#  (skip_28, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_29, None),
#  (init_loop_12, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (tauSplit_9, None),
#  (skip_3, None),
#  (skip_30, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_11, None),
#  (skip_8, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_15, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_14, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (skip_27, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (skip_26, None),
#  (init_loop_12, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_17, None),
#  (skip_14, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_28, None),
#  (skip_16, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_29, None),
#  (skip_11, None),
#  (skip_15, None),
#  (init_loop_17, None),
#  (skip_16, None),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_17, None),
#  (init_loop_12, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_30, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (skip_3, None),
#  (skip_16, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_3, None),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_22, None),
#  (init_loop_17, None),
#  (skip_11, None),
#  (init_loop_12, None),
#  (skip_21, None),
#  (skip_16, None),
#  (init_loop_17, None),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_15, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_16, None),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (tauJoin_10, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_14, None),
#  (skip_11, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (ec9d88c7-ba4a-4351-9915-ca1c0d8a7f7d, 'add_pepper'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_12, None),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_17, None),
#  (skip_11, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (091c348a-43a3-435f-8ae8-b30134593ae7, 'place_cheese_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_16, None),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (573d264d-38ac-478c-b3c9-523e1999aae0, 'peel_cucumber'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_25, None),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (e1dab229-cb32-4ffd-8f86-14df199a838c, 'cut_tomato'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (f08eb743-77d0-4e3f-846e-b8638d9fe3df, 'add_salt'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (init_loop_22, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (skip_24, None),
#  (skip_21, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (tauSplit_9, None),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (tauJoin_10, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_15, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (skip_14, None),
#  (skip_3, None),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_25, None),
#  (skip_8, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_19, None),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_24, None),
#  (skip_27, None),
#  (skip_25, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_20, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_15, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_24, None),
#  (init_loop_22, None),
#  (skip_14, None),
#  (skip_26, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_12, None),
#  (710b2b39-431c-4fe3-a010-26a8442fe7b5, 'place_lettuce_into_bowl'),
#  (4b26f01c-29f2-499b-a0fe-83320723afb4, 'mix_dressing'),
#  (skip_28, None),
#  (skip_11, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_15, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_21, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (30f72214-510d-43e8-ba90-0483c5f50680, 'cut_cucumber'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222, 'mix_ingredients'),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_19, None),
#  (skip_29, None),
#  (init_loop_12, None),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_11, None),
#  (caaa7c75-33ef-49f3-a96c-f43f12324484, 'serve_salad_onto_plate'),
#  (79d5922e-d2cb-4f6e-9c66-7b2a1022e16c, 'place_tomato_into_bowl'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_14, None),
#  (skip_20, None),
#  (skip_30, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_25, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (init_loop_22, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_3, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (skip_14, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (skip_24, None),
#  (init_loop_12, None),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_11, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_15, None),
#  (c5f7565e-94cf-4fa9-b0bc-879dbc339397, 'add_dressing'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (skip_21, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (skip_25, None),
#  (skip_3, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (b9ee192d-6f83-402b-8f06-b1b529d19e4a, 'place_cucumber_into_bowl'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (skip_24, None),
#  (init_loop_12, None),
#  (init_loop_22, None),
#  (init_loop_12, None),
#  (skip_11, None),
#  (skip_21, None),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (init_loop_17, None),
#  (init_loop_12, None),
#  (skip_16, None),
#  (7653de03-a2bc-4041-9155-a8ddef1c9eb2, 'add_oil'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (d1ab66f1-bb11-4263-a263-2d6ea71d302a, 'add_vinegar'),
#  (e6fa6179-4dee-4ddb-8c5f-fb6b3d235600, 'cut_lettuce'),
#  (38f24f27-ee1a-4e7e-aa0d-88e055902a52, 'cut_cheese'),
#  ...}

# %%
for transition in rg.transitions:
    transition_name = tuple(s.strip(" '") for s in transition.name.strip("()").split(","))
    # if (transition.from_state.name, transition.to_state.name) in rg_nx.edges():
    #     print(f"edge already exists: {transition.from_state.name} -> {transition.to_state.name}")
    #     rg_nx[transition.from_state.name][transition.to_state.name]['label'] = (*rg_nx[transition.from_state.name][transition.to_state.name]['label'], transition_name)
    # else:
    rg_nx.add_edge(
        transition.from_state.name,
        transition.to_state.name,
        label=transition_name
    )

# %%
# Dictionary to collect edges for each directed node pair
directed_pairs = {}

# Iterate over all edges in the MultiDiGraph
for u, v, key, data in rg_nx.edges(data=True, keys=True):
    # Use tuple (u, v) as the key to group edges
    directed_pairs.setdefault((u, v), []).append(data.get("label"))

# Process each pair to check if there are multiple edges; then print the labels.
for (u, v), labels in directed_pairs.items():
    if len(labels) > 1:
        print(f"Directed pair ({u}, {v}) has {len(labels)} edges with labels: {labels}")
# Out:
# Directed pair (p_111p_231p_321p_51p_81p_91, p_121p_231p_321p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_231p_321p_51p_81p_91, p_111p_231p_331p_51p_81p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_221p_281p_51p_71p_91, p_121p_221p_281p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_221p_261p_61p_71, p_101p_121p_221p_261p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_211p_331p_51p_81p_91, p_121p_211p_331p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_221p_321p_51p_71p_91, p_111p_221p_331p_51p_71p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_221p_321p_51p_71p_91, p_121p_221p_321p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_221p_291p_61p_71, p_101p_121p_221p_291p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_211p_341p_51p_81p_91, p_121p_211p_341p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_121p_181p_61p_71, p_101p_121p_201p_61p_71) has 5 edges with labels: [('ec9d88c7-ba4a-4351-9915-ca1c0d8a7f7d', 'add_pepper'), ('e1dab229-cb32-4ffd-8f86-14df199a838c', 'cut_tomato'), ('091c348a-43a3-435f-8ae8-b30134593ae7', 'place_cheese_into_bowl'), ('f08eb743-77d0-4e3f-846e-b8638d9fe3df', 'add_salt'), ('573d264d-38ac-478c-b3c9-523e1999aae0', 'peel_cucumber')]
# Directed pair (p_111p_221p_271p_51p_71p_91, p_121p_221p_271p_51p_71p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_221p_281p_61p_71, p_101p_121p_221p_281p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_231p_341p_51p_81p_91, p_121p_231p_341p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_221p_331p_51p_71p_91, p_121p_221p_331p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_221p_321p_61p_71, p_101p_111p_221p_331p_61p_71) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_101p_111p_221p_321p_61p_71, p_101p_121p_221p_321p_61p_71) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_231p_331p_51p_81p_91, p_121p_231p_331p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_221p_341p_51p_71p_91, p_121p_221p_341p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_221p_271p_61p_71, p_101p_121p_221p_271p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_121p_211p_321p_51p_81p_91, p_121p_211p_331p_51p_81p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_241p_341p_51p_81p_91, p_121p_241p_341p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_221p_301p_51p_71p_91, p_121p_221p_301p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_221p_331p_61p_71, p_101p_121p_221p_331p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_241p_331p_51p_81p_91, p_121p_241p_331p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_231p_281p_51p_71p_91, p_121p_231p_281p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_221p_341p_61p_71, p_101p_121p_221p_341p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_241p_321p_51p_81p_91, p_111p_241p_331p_51p_81p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_241p_321p_51p_81p_91, p_121p_241p_321p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_121p_151p_61p_71, p_101p_121p_141p_61p_71) has 2 edges with labels: [('caaa7c75-33ef-49f3-a96c-f43f12324484', 'serve_salad_onto_plate'), ('skip_30', 'None')]
# Directed pair (p_111p_211p_321p_51p_71p_91, p_111p_211p_331p_51p_71p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_211p_321p_51p_71p_91, p_121p_211p_321p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_221p_301p_61p_71, p_101p_121p_221p_301p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_241p_281p_51p_81p_91, p_121p_241p_281p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_211p_271p_51p_71p_91, p_121p_211p_271p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_231p_281p_61p_71, p_101p_121p_231p_281p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_121p_231p_321p_51p_81p_91, p_121p_231p_331p_51p_81p_91) has 3 edges with labels: [('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl'), ('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients')]
# Directed pair (p_111p_231p_291p_51p_81p_91, p_121p_231p_291p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_231p_271p_51p_71p_91, p_121p_231p_271p_51p_71p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_211p_321p_61p_71, p_101p_111p_211p_331p_61p_71) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_101p_111p_211p_321p_61p_71, p_101p_121p_211p_321p_61p_71) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_121p_221p_321p_51p_71p_91, p_121p_221p_331p_51p_71p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_211p_301p_51p_81p_91, p_121p_211p_301p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_241p_271p_51p_71p_91, p_121p_241p_271p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_211p_271p_61p_71, p_101p_121p_211p_271p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_231p_301p_51p_81p_91, p_121p_231p_301p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_231p_321p_51p_71p_91, p_111p_231p_331p_51p_71p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_231p_321p_51p_71p_91, p_121p_231p_321p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_231p_271p_61p_71, p_101p_121p_231p_271p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_241p_301p_51p_81p_91, p_121p_241p_301p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_211p_331p_51p_71p_91, p_121p_211p_331p_51p_71p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_241p_271p_61p_71, p_101p_121p_241p_271p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_241p_291p_51p_81p_91, p_121p_241p_291p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p
has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_221p_321p_51p_81p_91, p_121p_221p_321p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_221p_321p_51p_81p_91, p_111p_221p_331p_51p_81p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_101p_111p_181p_61p_71, p_101p_121p_181p_61p_71) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_181p_61p_71, p_101p_111p_201p_61p_71) has 5 edges with labels: [('ec9d88c7-ba4a-4351-9915-ca1c0d8a7f7d', 'add_pepper'), ('e1dab229-cb32-4ffd-8f86-14df199a838c', 'cut_tomato'), ('091c348a-43a3-435f-8ae8-b30134593ae7', 'place_cheese_into_bowl'), ('f08eb743-77d0-4e3f-846e-b8638d9fe3df', 'add_salt'), ('573d264d-38ac-478c-b3c9-523e1999aae0', 'peel_cucumber')]
# Directed pair (p_111p_221p_271p_51p_81p_91, p_121p_221p_271p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_201p_61p_71, p_101p_121p_201p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_221p_331p_51p_81p_91, p_121p_221p_331p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_211p_261p_61p_71, p_101p_121p_211p_261p_61p_71) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_111p_221p_341p_51p_81p_91, p_121p_221p_341p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_191p_61p_71, p_101p_121p_191p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_221p_301p_51p_81p_91, p_121p_221p_301p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_171p_61p_71, p_101p_121p_171p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_231p_281p_51p_81p_91, p_121p_231p_281p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_151p_61p_71, p_101p_111p_141p_61p_71) has 2 edges with labels: [('caaa7c75-33ef-49f3-a96c-f43f12324484', 'serve_salad_onto_plate'), ('skip_30', 'None')]
# Directed pair (p_101p_111p_151p_61p_71, p_101p_121p_151p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_211p_321p_51p_81p_91, p_111p_211p_331p_51p_81p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_211p_321p_51p_81p_91, p_121p_211p_321p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]
# Directed pair (p_101p_111p_141p_61p_71, p_101p_121p_141p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_211p_271p_51p_81p_91, p_121p_211p_271p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_211p_291p_61p_71, p_101p_121p_211p_291p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_111p_231p_271p_51p_81p_91, p_121p_231p_271p_51p_81p_91) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_211p_281p_61p_71, p_101p_121p_211p_281p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_101p_111p_231p_261p_61p_71, p_101p_121p_231p_261p_61p_71) has 2 edges with labels: [('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing'), ('skip_3', 'None')]
# Directed pair (p_121p_221p_321p_51p_81p_91, p_121p_221p_331p_51p_81p_91) has 3 edges with labels: [('4b26f01c-29f2-499b-a0fe-83320723afb4', 'mix_dressing'), ('ef0f8f7b-273c-4e5f-a1b5-e5ed6d8d0222', 'mix_ingredients'), ('79d5922e-d2cb-4f6e-9c66-7b2a1022e16c', 'place_tomato_into_bowl')]
# Directed pair (p_111p_241p_271p_51p_81p_91, p_121p_241p_271p_51p_81p_91) has 2 edges with labels: [('skip_3', 'None'), ('c5f7565e-94cf-4fa9-b0bc-879dbc339397', 'add_dressing')]

# %%
nodes = sorted(rg_nx.nodes())
num_transitions = len(transition_names)
num_nodes = len(nodes)
transition_matrix = np.zeros((num_transitions, num_nodes, num_nodes), dtype=int)

for edge in rg_nx.edges(data=True):
    from_node = nodes.index(edge[0])
    to_node = nodes.index(edge[1])
    transition_name = edge[2]['label'][1]
    if transition_name in transition_name_index:
        transition_idx = transition_name_index[transition_name]
        transition_matrix[transition_idx, from_node, to_node] = 1
    else:
        raise RuntimeError(f"somehow, transition: {transition_name} was encountered but not indexed")

# %%
for i in range(num_nodes):
    for j in range(num_nodes):
        count = 0
        for k in range(num_transitions):
            if transition_matrix[k, i, j] == 1:
                count += 1
            if count > 3:
                print(f"Transition {k} from {i} to {j}")
# Out:
# Transition 15 from 16 to 24
# Transition 16 from 16 to 24
# Transition 17 from 16 to 24
# Transition 18 from 16 to 24
# Transition 19 from 16 to 24
# Transition 20 from 16 to 24
# Transition 15 from 17 to 25
# Transition 16 from 17 to 25
# Transition 17 from 17 to 25
# Transition 18 from 17 to 25
# Transition 19 from 17 to 25
# Transition 20 from 17 to 25
# Transition 15 from 18 to 26
# Transition 16 from 18 to 26
# Transition 17 from 18 to 26
# Transition 18 from 18 to 26
# Transition 19 from 18 to 26
# Transition 20 from 18 to 26
# Transition 15 from 19 to 27
# Transition 16 from 19 to 27
# Transition 17 from 19 to 27
# Transition 18 from 19 to 27
# Transition 19 from 19 to 27
# Transition 20 from 19 to 27
# Transition 15 from 172 to 180
# Transition 16 from 172 to 180
# Transition 17 from 172 to 180
# Transition 18 from 172 to 180
# Transition 19 from 172 to 180
# Transition 20 from 172 to 180
# Transition 15 from 173 to 181
# Transition 16 from 173 to 181
# Transition 17 from 173 to 181
# Transition 18 from 173 to 181
# Transition 19 from 173 to 181
# Transition 20 from 173 to 181
# Transition 15 from 174 to 182
# Transition 16 from 174 to 182
# Transition 17 from 174 to 182
# Transition 18 from 174 to 182
# Transition 19 from 174 to 182
# Transition 20 from 174 to 182
# Transition 15 from 175 to 183
# Transition 16 from 175 to 183
# Transition 17 from 175 to 183
# Transition 18 from 175 to 183
# Transition 19 from 175 to 183
# Transition 20 from 175 to 183
# Transition 15 from 328 to 336
# Transition 16 from 328 to 336
# Transition 17 from 328 to 336
# Transition 18 from 328 to 336
# Transition 19 from 328 to 336
# Transition 20 from 328 to 336
# Transition 15 from 329 to 337
# Transition 16 from 329 to 337
# Transition 17 from 329 to 337
# Transition 18 from 329 to 337
# Transition 19 from 329 to 337
# Transition 20 from 329 to 337
# Transition 15 from 330 to 338
# Transition 16 from 330 to 338
# Transition 17 from 330 to 338
# Transition 18 from 330 to 338
# Transition 19 from 330 to 338
# Transition 20 from 330 to 338
# Transition 15 from 331 to 339
# Transition 16 from 331 to 339
# Transition 17 from 331 to 339
# Transition 18 from 331 to 339
# Transition 19 from 331 to 339
# Transition 20 from 331 to 339
# Transition 15 from 484 to 492
# Transition 16 from 484 to 492
# Transition 17 from 484 to 492
# Transition 18 from 484 to 492
# Transition 19 from 484 to 492
# Transition 20 from 484 to 492
# Transition 15 from 485 to 493
# Transition 16 from 485 to 493
# Transition 17 from 485 to 493
# Transition 18 from 485 to 493
# Transition 19 from 485 to 493
# Transition 20 from 485 to 493
# Transition 15 from 486 to 494
# Transition 16 from 486 to 494
# Transition 17 from 486 to 494
# Transition 18 from 486 to 494
# Transition 19 from 486 to 494
# Transition 20 from 486 to 494
# Transition 15 from 487 to 495
# Transition 16 from 487 to 495
# Transition 17 from 487 to 495
# Transition 18 from 487 to 495
# Transition 19 from 487 to 495
# Transition 20 from 487 to 495
