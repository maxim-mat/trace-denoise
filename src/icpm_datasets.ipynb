# %%
import pm4py
from pm4py.objects.log.importer.xes import importer as xes_importer
import numpy as np
from itertools import chain
from sklearn.preprocessing import OneHotEncoder
import pickle as pkl
import sklearn.metrics as metrics

# %%
def add_dirichlet_noise(p, alpha=0.1, noise_level=0.1):
    """
    p: original probability vector (e.g., one-hot)
    alpha: concentration parameter for the Dirichlet distribution.
           Lower alpha makes the Dirichlet sample more "peaky".
    noise_level: mixing coefficient for the noise.
    """
    # Generate a Dirichlet noise vector.
    noise = np.random.dirichlet(np.ones_like(p) * alpha)
    # Mix the original distribution with the noise.
    perturbed = (1 - noise_level) * p + noise_level * noise
    # Ensure it sums to 1.
    perturbed /= perturbed.sum()
    return perturbed

# %%
bpi12_factory = xes_importer.apply(r"../data/BPI_Challenge_2019.xes")
# Out:
# parsing log, completed traces ::   0%|          | 0/251734 [00:00<?, ?it/s]

# %%
all_activities_bpi12 = set()
for trace in bpi12_factory:
    for event in trace:
        all_activities_bpi12.add(event['concept:name'])

# %%
activity_to_int_bpi12 = {str(idx): act for idx, act in enumerate(sorted(all_activities_bpi12))}

# %%
activity_to_int_bpi12
# Out:
# {'0': 'Block Purchase Order Item',
#  '1': 'Cancel Goods Receipt',
#  '2': 'Cancel Invoice Receipt',
#  '3': 'Cancel Subsequent Invoice',
#  '4': 'Change Approval for Purchase Order',
#  '5': 'Change Currency',
#  '6': 'Change Delivery Indicator',
#  '7': 'Change Final Invoice Indicator',
#  '8': 'Change Price',
#  '9': 'Change Quantity',
#  '10': 'Change Rejection Indicator',
#  '11': 'Change Storage Location',
#  '12': 'Change payment term',
#  '13': 'Clear Invoice',
#  '14': 'Create Purchase Order Item',
#  '15': 'Create Purchase Requisition Item',
#  '16': 'Delete Purchase Order Item',
#  '17': 'Reactivate Purchase Order Item',
#  '18': 'Receive Order Confirmation',
#  '19': 'Record Goods Receipt',
#  '20': 'Record Invoice Receipt',
#  '21': 'Record Service Entry Sheet',
#  '22': 'Record Subsequent Invoice',
#  '23': 'Release Purchase Order',
#  '24': 'Release Purchase Requisition',
#  '25': 'Remove Payment Block',
#  '26': 'SRM: Awaiting Approval',
#  '27': 'SRM: Change was Transmitted',
#  '28': 'SRM: Complete',
#  '29': 'SRM: Created',
#  '30': 'SRM: Deleted',
#  '31': 'SRM: Document Completed',
#  '32': 'SRM: Held',
#  '33': 'SRM: In Transfer to Execution Syst.',
#  '34': 'SRM: Incomplete',
#  '35': 'SRM: Ordered',
#  '36': 'SRM: Transaction Completed',
#  '37': 'SRM: Transfer Failed (E.Sys.)',
#  '38': 'Set Payment Block',
#  '39': 'Update Order Confirmation',
#  '40': 'Vendor creates debit memo',
#  '41': 'Vendor creates invoice'}

# %%
activity_to_int = {v: int(k) for k, v in activity_to_int_bpi12.items()}

# %%
tokenized_traces = [
    np.array([activity_to_int[event['concept:name']] for event in trace])
    for trace in bpi12_factory
]

# %%
encoder = OneHotEncoder(sparse_output=False)
encoder.fit(np.array(list(chain.from_iterable(tokenized_traces))).reshape(-1, 1))
one_hot_bpi12 = [encoder.transform(x.reshape(-1, 1)) for x in tokenized_traces]

# %%
simple_noisy_dataset12 = [np.array([add_dirichlet_noise(x, alpha=0.04, noise_level=0.55) for x in t]) for t in one_hot_bpi12]

# %%
np.mean([metrics.accuracy_score(np.argmax(t, axis=1), np.argmax(s, axis=1)) for t, s in zip(one_hot_bpi12, simple_noisy_dataset12)])
# Out:
# 0.8061501036059152

# %%
with open("../data/pickles/bpi17_unified.pkl", "wb") as f:
    pkl.dump({'target': one_hot_bpi12, 'stochastic': simple_noisy_dataset12}, f)

# %%
bpi19_factory = xes_importer.apply(r"../data/BPI_Challenge_2019.xes")
# Out:
# parsing log, completed traces ::   0%|          | 0/251734 [00:00<?, ?it/s]

# %%
all_activities_bpi19 = set()
for trace in bpi19_factory:
    for event in trace:
        all_activities_bpi19.add(event['concept:name'])
activity_to_int_bpi19 = {str(idx): act for idx, act in enumerate(sorted(all_activities_bpi19))}
activity_to_int_bpi19
# Out:
# {'0': 'Block Purchase Order Item',
#  '1': 'Cancel Goods Receipt',
#  '2': 'Cancel Invoice Receipt',
#  '3': 'Cancel Subsequent Invoice',
#  '4': 'Change Approval for Purchase Order',
#  '5': 'Change Currency',
#  '6': 'Change Delivery Indicator',
#  '7': 'Change Final Invoice Indicator',
#  '8': 'Change Price',
#  '9': 'Change Quantity',
#  '10': 'Change Rejection Indicator',
#  '11': 'Change Storage Location',
#  '12': 'Change payment term',
#  '13': 'Clear Invoice',
#  '14': 'Create Purchase Order Item',
#  '15': 'Create Purchase Requisition Item',
#  '16': 'Delete Purchase Order Item',
#  '17': 'Reactivate Purchase Order Item',
#  '18': 'Receive Order Confirmation',
#  '19': 'Record Goods Receipt',
#  '20': 'Record Invoice Receipt',
#  '21': 'Record Service Entry Sheet',
#  '22': 'Record Subsequent Invoice',
#  '23': 'Release Purchase Order',
#  '24': 'Release Purchase Requisition',
#  '25': 'Remove Payment Block',
#  '26': 'SRM: Awaiting Approval',
#  '27': 'SRM: Change was Transmitted',
#  '28': 'SRM: Complete',
#  '29': 'SRM: Created',
#  '30': 'SRM: Deleted',
#  '31': 'SRM: Document Completed',
#  '32': 'SRM: Held',
#  '33': 'SRM: In Transfer to Execution Syst.',
#  '34': 'SRM: Incomplete',
#  '35': 'SRM: Ordered',
#  '36': 'SRM: Transaction Completed',
#  '37': 'SRM: Transfer Failed (E.Sys.)',
#  '38': 'Set Payment Block',
#  '39': 'Update Order Confirmation',
#  '40': 'Vendor creates debit memo',
#  '41': 'Vendor creates invoice'}

# %%
r_activity_to_int_bpi19 = {act: idx for idx, act in enumerate(sorted(all_activities_bpi19))}

# %%
tokenized_traces = [
    np.array([r_activity_to_int_bpi19[event['concept:name']] for event in trace])
    for trace in bpi19_factory
]
encoder = OneHotEncoder(sparse_output=False)
encoder.fit(np.array(list(chain.from_iterable(tokenized_traces))).reshape(-1, 1))
one_hot_bpi19 = [encoder.transform(x.reshape(-1, 1)) for x in tokenized_traces]

# %%
simple_noisy_dataset19 = [np.array([add_dirichlet_noise(x, alpha=0.04, noise_level=0.6) for x in t]) for t in one_hot_bpi19]

# %%
np.mean([metrics.accuracy_score(np.argmax(t, axis=1), np.argmax(s, axis=1)) for t, s in
         zip(one_hot_bpi19, simple_noisy_dataset19)])
# Out:
# 0.7919753616666503

# %%
with open("../data/pickles/bpi19_unified.pkl", "wb") as f:
    pkl.dump({'target': one_hot_bpi19, 'stochastic': simple_noisy_dataset19}, f)

# %%
max([x.shape[0] for x in one_hot_bpi19])
# Out:
# 990

# %%
from sktr_update.utils import group_cases_by_trace
from sktr_update.utils import prepare_df_from_dataset

# our refactored comparison function
from sktr_update.core import compare_stochastic_vs_argmax_random_indices

# %%
with open(r"../data/pickles/bpi12_reduced.pkl", "rb") as f:
    bpi12 = pkl.load(f)

with open(r"../data/pickles/bpi19_reduced.pkl", "rb") as f:
    bpi19 = pkl.load(f)

# %%
one_hot_bpi12, simple_noisy_dataset12 = bpi12["target"], bpi12["stochastic"]
one_hot_bpi19, simple_noisy_dataset19 = bpi19["target"], bpi19["stochastic"]

# %%
bpi12_target_sktr = [np.argmax(t, axis=1) for t in one_hot_bpi12]
bpi12_source_sktr = [x.T for x in simple_noisy_dataset12]
bpi19_target_sktr = [np.argmax(t, axis=1) for t in one_hot_bpi19]
bpi19_source_sktr = [x.T for x in simple_noisy_dataset19]

# %%
df12, softmax_lst12 = prepare_df_from_dataset(bpi12_target_sktr, bpi12_source_sktr)
df19, softmax_lst19 = prepare_df_from_dataset(bpi19_target_sktr, bpi19_source_sktr)

# %%
recovery_results_df, alignment_results_df, model = compare_stochastic_vs_argmax_random_indices(
    df=df12,
    softmax_lst=softmax_lst12,
    n_indices=60,
    activity_prob_threshold=0.01,
    cost_function='logarithmic',
    random_seed=42,
    train_cases=None,
    test_cases=None,
    n_train_traces=10,
    n_test_traces=20,
    allow_train_test_case_overlap=False,
    allow_duplicate_variants=True,
    sequential_sampling=True,
    round_precision=4,
    return_model=True,
    lambdas=[0.1, 0.3, 0.6],
    alpha=0.6,
    use_cond_probs=True,
    use_calibration=True,
    use_ngram_smoothing=False,
    temp_bounds=(1, 5)
)
case_lists = recovery_results_df.groupby("case:concept:name")[["sktr_pred", "argmax_pred", "ground_truth"]].apply(lambda g: g.values.tolist()).tolist()
sktr_result12 = [[int(x[0]) for x in y if x[0] is not None] for y in case_lists]
sktr_gt12 = [[int(x[2]) for x in y if x[0] is not None] for y in case_lists]
bpi12_accuracy = np.mean([metrics.accuracy_score(t, s) for t, s in zip(sktr_gt12, sktr_result12)])
# Out:
# 2025-05-17 10:43:23 - INFO - Starting comparison.
# 2025-05-17 10:43:23 - DEBUG - Validating input parameters.
# 2025-05-17 10:43:23 - DEBUG - Input parameters validation passed.
# 2025-05-17 10:43:23 - DEBUG - Processing cost function: logarithmic
# 2025-05-17 10:43:23 - DEBUG - Using logarithmic cost function.
# 2025-05-17 10:43:23 - DEBUG - Setting random seed to 42.
# 2025-05-17 10:43:23 - DEBUG - === Entering filter_indices block ===
# 2025-05-17 10:43:23 - DEBUG - Input softmax_lst: 4000 matrices
# 2025-05-17 10:43:23 - DEBUG - Preparing softmax list.
3), (24, 3), (24, 3), (24, 32), (24, 32), (24, 6), (24, 8), (24, 33), (24, 32), (24, 30), (24, 42), (24, 3), (24, 25), (24, 3), (24, 6), (24, 43), (24, 6), (24, 3), (24, 6), (24, 6), (24, 65), (24, 3), (24, 45), (24, 3), (24, 31), (24, 3), (24, 33), (24, 3), (24, 14), (24, 6), (24, 27), (24, 3), (24, 6), (24, 3), (24, 3), (24, 6), (24, 54), (24, 10), (24, 44), (24, 18), (24, 7), (24, 10), (24, 6), (24, 18), (24, 3), (24, 8), (24, 3), (24, 37), (24, 57), (24, 17), (24, 3), (24, 3), (24, 6), (24, 3), (24, 9), (24, 44), (24, 10), (24, 3), (24, 11), (24, 3), (24, 6), (24, 39), (24, 24), (24, 3), (24, 6), (24, 58), (24, 6), (24, 42), (24, 6), (24, ...
# 2025-05-17 10:43:24 - DEBUG - === Exiting filter_indices block ===
# 2025-05-17 10:43:24 - DEBUG - Splitting data into train/test sets.
# 2025-05-17 10:43:25 - INFO - Train traces: 10, Test traces: 20
# 2025-05-17 10:43:25 - DEBUG - Preparing log for discovery.
# 2025-05-17 10:43:25 - INFO - Petri net discovered.
# 2025-05-17 10:43:25 - DEBUG - Building conditional probability dictionary.
# 2025-05-17 10:43:25 - INFO - Probability dictionary built.
# 2025-05-17 10:43:26 - INFO - Optimal temperature: 1.0
# 2025-05-17 10:43:26 - INFO - Calibration complete.
# 2025-05-17 10:43:26 - INFO - Processing 20 test cases.
# 2025-05-17 10:43:26 - DEBUG - Case 1/20: 3492, matrix shape=(24, 3)
# 2025-05-17 10:43:26 - DEBUG - Calculated accuracy: 1.0 (correct=3, total=3)
# 2025-05-17 10:43:26 - DEBUG - Calculated accuracy: 1.0 (correct=3, total=3)
# 2025-05-17 10:43:26 - DEBUG - Case 2/20: 3728, matrix shape=(24, 3)
# 2025-05-17 10:43:26 - DEBUG - Calculated accuracy: 1.0 (correct=3, total=3)
# 2025-05-17 10:43:26 - DEBUG - Calculated accuracy: 0.0 (correct=0, total=3)
# 2025-05-17 10:43:26 - DEBUG - Case 3/20: 688, matrix shape=(24, 16)
# 2025-05-17 10:43:35 - DEBUG - Calculated accuracy: 1.0 (correct=16, total=16)
# 2025-05-17 10:43:35 - DEBUG - Calculated accuracy: 0.75 (correct=12, total=16)
# 2025-05-17 10:43:35 - DEBUG - Case 4/20: 3007, matrix shape=(24, 51)
# 2025-05-17 10:45:15 - DEBUG - Calculated accuracy: 0.7647 (correct=39, total=51)
# 2025-05-17 10:45:15 - DEBUG - Calculated accuracy: 0.7451 (correct=38, total=51)
# 2025-05-17 10:45:15 - DEBUG - Case 5/20: 1318, matrix shape=(24, 7)
# 2025-05-17 10:45:16 - DEBUG - Calculated accuracy: 1.0 (correct=7, total=7)
# 2025-05-17 10:45:16 - DEBUG - Calculated accuracy: 1.0 (correct=7, total=7)
# 2025-05-17 10:45:16 - DEBUG - Case 6/20: 3174, matrix shape=(24, 47)
# 2025-05-17 10:46:25 - DEBUG - Calculated accuracy: 1.0 (correct=47, total=47)
# 2025-05-17 10:46:25 - DEBUG - Calculated accuracy: 0.9149 (correct=43, total=47)
# 2025-05-17 10:46:25 - DEBUG - Case 7/20: 2553, matrix shape=(24, 8)
# 2025-05-17 10:46:27 - DEBUG - Calculated accuracy: 1.0 (correct=8, total=8)
# 2025-05-17 10:46:27 - DEBUG - Calculated accuracy: 0.875 (correct=7, total=8)
# 2025-05-17 10:46:27 - DEBUG - Case 8/20: 1114, matrix shape=(24, 3)
# 2025-05-17 10:46:27 - DEBUG - Calculated accuracy: 1.0 (correct=3, total=3)
# 2025-05-17 10
- DEBUG - Calculated accuracy: 1.0 (correct=3, total=3)
# 2025-05-17 10:51:42 - DEBUG - Calculated accuracy: 0.3333 (correct=1, total=3)

# %%
bpi12_accuracy
# Out:
# 0.9409631863498088

# %%
np.mean([metrics.recall_score(t, s, average="macro", zero_division=0) for t, s in zip(sktr_gt12, sktr_result12)])
# Out:
# 0.8950357228329041

# %%
np.mean([metrics.precision_score(t, s, average="macro", zero_division=0) for t, s in zip(sktr_gt12, sktr_result12)])
# Out:
# 0.8858285356406601

# %% [markdown]
# bpi12 200 accuracy: 0.938 precision: 0.855 recall: 0.858

# %%
recovery_results_df, alignment_results_df, model = compare_stochastic_vs_argmax_random_indices(
    df=df19,
    softmax_lst=softmax_lst19,
    n_indices=60,
    activity_prob_threshold=0.01,
    cost_function='logarithmic',
    random_seed=42,
    train_cases=None,
    test_cases=None,
    n_train_traces=10,
    n_test_traces=20,
    allow_train_test_case_overlap=False,
    allow_duplicate_variants=True,
    sequential_sampling=True,
    round_precision=4,
    return_model=True,
    lambdas=[0.1, 0.3, 0.6],
    alpha=0.6,
    use_cond_probs=True,
    use_calibration=True,
    use_ngram_smoothing=False,
    temp_bounds=(1, 5)
)
case_lists = recovery_results_df.groupby("case:concept:name")[["sktr_pred", "argmax_pred", "ground_truth"]].apply(lambda g: g.values.tolist()).tolist()
sktr_result19 = [[int(x[0]) for x in y if x[0] is not None] for y in case_lists]
sktr_gt19 = [[int(x[2]) for x in y if x[0] is not None] for y in case_lists]
bpi19_accuracy = np.mean([metrics.accuracy_score(t, s) for t, s in zip(sktr_gt19, sktr_result19)])
# Out:
# 2025-05-17 11:00:05 - INFO - Starting comparison.
# 2025-05-17 11:00:05 - DEBUG - Validating input parameters.
# 2025-05-17 11:00:05 - DEBUG - Input parameters validation passed.
# 2025-05-17 11:00:05 - DEBUG - Processing cost function: logarithmic
# 2025-05-17 11:00:05 - DEBUG - Using logarithmic cost function.
# 2025-05-17 11:00:05 - DEBUG - Setting random seed to 42.
# 2025-05-17 11:00:05 - DEBUG - === Entering filter_indices block ===
# 2025-05-17 11:00:05 - DEBUG - Input softmax_lst: 4000 matrices
# 2025-05-17 11:00:05 - DEBUG - Preparing softmax list.
# 2025-05-17 11:00:05 - DEBUG - prepare_softmax returned list of 4000 arrays, shapes=[(42, 5), (42, 5), (42, 6), (42, 9), (42, 6), (42, 7), (42, 6), (42, 6), (42, 5), (42, 5), (42, 5), (42, 5), (42, 6), (42, 5), (42, 6), (42, 8), (42, 6), (42, 6), (42, 6), (42, 1), (42, 5), (42, 5), (42, 5), (42, 5), (42, 19), (42, 2), (42, 1), (42, 6), (42, 5), (42, 2), (42, 7), (42, 6), (42, 5), (42, 5), (42, 6), (42, 9), (42, 7), (42, 5), (42, 4), (42, 2), (42, 5), (42, 6), (42, 5), (42, 6), (42, 4), (42, 4), (42, 6), (42, 3), (42, 6), (42, 5), (42, 5), (42, 2), (42, 6), (42, 5), (42, 5), (42, 6), (42, 5), (42, 5), (42,
# 2025-05-17 11:00:06 - DEBUG - Building conditional probability dictionary.
# 2025-05-17 11:00:06 - INFO - Probability dictionary built.
# 2025-05-17 11:00:06 - INFO - Optimal temperature: 1.0
# 2025-05-17 11:00:06 - INFO - Calibration complete.
# 2025-05-17 11:00:06 - INFO - Processing 20 test cases.
# 2025-05-17 11:00:06 - DEBUG - Case 1/20: 3492, matrix shape=(42, 17)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.7647 (correct=13, total=17)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.7647 (correct=13, total=17)
# 2025-05-17 11:00:06 - DEBUG - Case 2/20: 3728, matrix shape=(42, 5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:06 - DEBUG - Case 3/20: 688, matrix shape=(42, 5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.8 (correct=4, total=5)
# 2025-05-17 11:00:06 - DEBUG - Case 4/20: 3007, matrix shape=(42, 6)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=6, total=6)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=6, total=6)
# 2025-05-17 11:00:06 - DEBUG - Case 5/20: 1318, matrix shape=(42, 5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.8 (correct=4, total=5)
# 2025-05-17 11:00:06 - DEBUG - Case 6/20: 3174, matrix shape=(42, 10)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.8 (correct=8, total=10)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.9 (correct=9, total=10)
# 2025-05-17 11:00:06 - DEBUG - Case 7/20: 2553, matrix shape=(42, 5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.8 (correct=4, total=5)
# 2025-05-17 11:00:06 - DEBUG - Case 8/20: 1114, matrix shape=(42, 5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.6 (correct=3, total=5)
# 2025-05-17 11:00:06 - DEBUG - Case 9/20: 1107, matrix shape=(42, 6)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=6, total=6)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.8333 (correct=5, total=6)
# 2025-05-17 11:00:06 - DEBUG - Case 10/20: 1342, matrix shape=(42, 3)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.6667 (correct=2, total=3)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=3, total=3)
# 2025-05-17 11:00:06 - DEBUG - Case 11/20: 1803, matrix shape=(42, 5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.4 (correct=2, total=5)
# 2025-05-17 11:00:06 - DEBUG - Case 12/20: 1855, matrix shape=(42, 3)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.6667 (correct=2, total=3)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.6667 (correct=2, total=3)
# 2025-05-17 11:00:06 - DEBUG - Case 13/20: 2860, matrix shape=(42, 5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.6 (correct=3, total=5)
# 2025-05-17 11:00:06 - DEBUG - Case 14/20: 3216, matrix shape=(42, 6)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.8333 (correct=5, total=6)
# 2025-05-17 11:00:06 - DEBUG - Calculated accuracy: 0.8333 (correct=5, total=6)
# 2025-05-17 11:00:06 - DEBUG - Case 15/20: 1095, matrix shape=(42, 3)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 0.3333 (correct=1, total=3)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 1.0 (correct=3, total=3)
# 2025-05-17 11:00:07 - DEBUG - Case 16/20: 3066, matrix shape=(42, 6)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 1.0 (correct=6, total=6)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 0.6667 (correct=4, total=6)
# 2025-05-17 11:00:07 - DEBUG - Case 17/20: 1730, matrix shape=(42, 6)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 0.8333 (correct=5, total=6)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 0.8333 (correct=5, total=6)
# 2025-05-17 11:00:07 - DEBUG - Case 18/20: 3637, matrix shape=(42, 5)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 1.0 (correct=5, total=5)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 0.6 (correct=3, total=5)
# 2025-05-17 11:00:07 - DEBUG - Case 19/20: 3393, matrix shape=(42, 10)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 0.8 (correct=8, total=10)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 1.0 (correct=10, total=10)
# 2025-05-17 11:00:07 - DEBUG - Case 20/20: 3583, matrix shape=(42, 8)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 0.625 (correct=5, total=8)
# 2025-05-17 11:00:07 - DEBUG - Calculated accuracy: 0.875 (correct=7, total=8)

# %%
bpi19_accuracy
# Out:
# 0.8661519607843138

# %%
np.mean([metrics.recall_score(t, s, average="macro", zero_division=0) for t, s in zip(sktr_gt19, sktr_result19)])
# Out:
# 0.8180753968253969

# %%
np.mean([metrics.precision_score(t, s, average="macro", zero_division=0) for t, s in zip(sktr_gt19, sktr_result19)])
# Out:
# 0.8041170634920635

# %% [markdown]
# bpi19 2000 accuracy: 0.942 precision: 0.916 recall: 0.91
# bpi19 20 accuracy: 0.866 precision: 0.804 recall: 0.818
